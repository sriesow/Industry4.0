# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load in 

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the "../input/" directory.
# For example, running this (by clicking run or pressing Shift+Enter) will list the files in the input directory

from subprocess import check_output
print(check_output(["ls", "./plant-seedlings"]).decode("utf8"))

import matplotlib.pyplot as plt
import seaborn as sns
import zipfile
import io
import os
import keras
from keras.models import Model, Sequential
from keras.utils import layer_utils
from keras.preprocessing import image
from keras.applications.vgg16 import VGG16,preprocess_input, decode_predictions

# Any results you write to the current directory are saved as output.
# Out:
# sample_submission.csv
# sample_submission.csv.zip
# test
# test.zip
# train
# train.zip
# Using TensorFlow backend.

# %%
from mpl_toolkits.axes_grid1 import ImageGrid
from tqdm import tqdm

# %%
# !ls ./plant-seedlings/train
# Out:
#  Black-grass	    'Common wheat'	'Scentless Mayweed'
#  Charlock	    'Fat Hen'		'Shepherds Purse'
#  Cleavers	    'Loose Silky-bent'	'Small-flowered Cranesbill'
# 'Common Chickweed'   Maize		'Sugar beet'

# %%
CATEGORIES = ['Black-grass', 'Charlock', 'Cleavers', 'Common Chickweed', 'Common wheat', 'Fat Hen', 'Loose Silky-bent',
              'Maize', 'Scentless Mayweed', 'Shepherds Purse', 'Small-flowered Cranesbill', 'Sugar beet']
NUM_CATEGORIES = len(CATEGORIES)

# %%
train_dir = './plant-seedlings/train'
test_dir = './plant-seedlings/test'

# %%
for category in CATEGORIES:
    print('{} {} images'.format(category, len(os.listdir(os.path.join(train_dir,category)))))
# Out:
# Black-grass 263 images
# Charlock 390 images
# Cleavers 287 images
# Common Chickweed 611 images
# Common wheat 221 images
# Fat Hen 475 images
# Loose Silky-bent 654 images
# Maize 221 images
# Scentless Mayweed 516 images
# Shepherds Purse 231 images
# Small-flowered Cranesbill 496 images
# Sugar beet 385 images

# %% [markdown]
# # Use Keras Pretrained Models dataset

# %%
# !ls ./models/
# Out:
# ls: cannot access './models/': No such file or directory

# %%
cache_dir = os.path.expanduser(os.path.join('~','.keras'))
if not os.path.exists(cache_dir):
    os.mkdir(cache_dir)
    
model_dir = os.path.join(cache_dir,'models')
if not os.path.exists(model_dir):
    os.mkdir(model_dir)

# %%
# !cp ../input/keras-pretrained-models/*notop* ~/.keras/models/

# %%
# !cp ../input/keras-pretrained-models/imagenet_class_index.json ~/.keras/models/
# !cp ../input/keras-pretrained-models/resnet50* ~/.keras/models/

# %%
# !ls ~/.keras/models
# Out:
# vgg16_weights_tf_dim_ordering_tf_kernels_notop.h5
# xception_weights_tf_dim_ordering_tf_kernels_notop.h5

# %% [markdown]
# # Check the plant seedlings

# %%
sample_per_category = 100
seed = 1999
data_dir = './plant-seedlings'
sample_submisson = pd.read_csv(os.path.join(data_dir,'sample_submission.csv'))

# %%
sample_submisson.head()
# Out:
#             file     species
# 0  0021e90e4.png  Sugar beet
# 1  003d61042.png  Sugar beet
# 2  007b3da8b.png  Sugar beet
# 3  0086a6340.png  Sugar beet
# 4  00c47e980.png  Sugar beet

# %%
train=[]
for category_id, category in enumerate(CATEGORIES):
    for file in os.listdir(os.path.join(train_dir,category)):
        train.append(['train/{}/{}'.format(category,file),category_id,category])

# %%
train = pd.DataFrame(train,columns=['file','category_id','category'])
train.head(2)
# Out:
#                               file  category_id     category
# 0  train/Black-grass/d8afd58f3.png            0  Black-grass
# 1  train/Black-grass/279ac215b.png            0  Black-grass

# %% [markdown]
# # Training sample

# %%
train = pd.concat(train[train['category']==c][:sample_per_category] for c in CATEGORIES)

# %%
train=train.sample(frac=1)
train.index=np.arange(len(train))

# %%
train.head(6)
# Out:
#                                             file  category_id  \
# 0                   train/Cleavers/d3a7492ff.png            2
# 1           train/Common Chickweed/ffc02550b.png            3
# 2                   train/Charlock/69734d263.png            1
# 3          train/Scentless Mayweed/2e4ae28f4.png            8
# 4                 train/Sugar beet/29d56fd75.png           11
# 5  train/Small-flowered Cranesbill/137126847.png           10
#
#                     category
# 0                   Cleavers
# 1           Common Chickweed
# 2                   Charlock
# 3          Scentless Mayweed
# 4                 Sugar beet
# 5  Small-flowered Cranesbill

# %%
train.shape
# Out:
# (1200, 3)

# %%
test = []
for file in os.listdir(test_dir):
    test.append(['test/{}'.format(file),file])
test=pd.DataFrame(test,columns=['file_path','file'])
test.head(2)
# Out:
#             file_path           file
# 0  test/7d3045fc3.png  7d3045fc3.png
# 1  test/8ece6efec.png  8ece6efec.png

# %%
test.shape
# Out:
# (794, 2)

# %%
def read_img(file_path,img_size):
    img = image.load_img(file_path,target_size=img_size)
    img = image.img_to_array(img)
    return img

# %%
img_sample=read_img(os.path.join(data_dir,train.loc[0,'file']),(224,224))

# %%
plt.imshow(img_sample/255)

# %% [markdown]
# # Example images

# %%
fig = plt.figure(1,figsize=(NUM_CATEGORIES,NUM_CATEGORIES))
grid = ImageGrid(fig, 111, nrows_ncols=(NUM_CATEGORIES,NUM_CATEGORIES), axes_pad=0.05)
i = 0
for category_id, category in enumerate(CATEGORIES):
    for file in train[train['category']==category]['file'].values[:NUM_CATEGORIES]:
        ax=grid[i]
        img = read_img(os.path.join(data_dir,file),(224,224))
        ax.imshow(img/255)
        ax.axis('off')
        if i%NUM_CATEGORIES == NUM_CATEGORIES-1:
            ax.text(250,112,file.split('/')[1], verticalalignment='center')
        i += 1
plt.show()

# %% [markdown]
# # Validation split

# %%
np.random.seed(seed)

# %%
rnd = np.random.random(len(train))
train_index = rnd<0.8
valid_index=rnd>=0.8
ytrain=train.loc[train_index,'category_id'].values
yvalid=train.loc[valid_index,'category_id'].values
len(ytrain),len(yvalid)
# Out:
# (918, 282)

# %% [markdown]
# # Extract VGG16 bottleneck features

# %%
INPUT_SIZE=224
POOLING='avg'
x_train=np.zeros((len(train),INPUT_SIZE,INPUT_SIZE,3),dtype=np.float32)
for i,file in tqdm(enumerate(train['file'])):
    img = read_img(os.path.join(data_dir,file),(INPUT_SIZE,INPUT_SIZE))
    x=preprocess_input(np.expand_dims(img.copy(),axis=0))
    x_train[i]=x
print('Train image shape: {} size: {:,}'.format(x_train.shape,x_train.size))
# Out:
# 1200it [00:11, 101.99it/s]
# Train image shape: (1200, 224, 224, 3) size: 180,633,600

# %%
xtrain=x_train[train_index]
xvalid=x_train[valid_index]
print((xtrain.shape,xvalid.shape))
# Out:
# ((918, 224, 224, 3), (282, 224, 224, 3))

# %%
vgg_bottleneck = VGG16(weights='imagenet', include_top=False, pooling=POOLING)

# %%
train_vgg_bf = vgg_bottleneck.predict(xtrain, batch_size=32, verbose=1)
valid_vgg_bf = vgg_bottleneck.predict(xvalid, batch_size=32, verbose=1)
print('VGG train bottleneck features shape: {} size: {:,}'.format(train_vgg_bf.shape, train_vgg_bf.size))
print('VGG valid bottleneck features shape: {} size: {:,}'.format(valid_vgg_bf.shape, valid_vgg_bf.size))
# Out:
# 918/918 [==============================] - 4s 5ms/step
# 282/282 [==============================] - 1s 5ms/step
# VGG train bottleneck features shape: (918, 512) size: 470,016
# VGG valid bottleneck features shape: (282, 512) size: 144,384

# %% [markdown]
# # try fully-connected layers

# %%
FCN = Sequential()

# %%
train_vgg_bf.shape
# Out:
# (918, 512)

# %%
one_hot_labels = keras.utils.to_categorical(ytrain, num_classes=12)

# %%
valid_labels = keras.utils.to_categorical(yvalid, num_classes=12)

# %%
FCN.add(keras.layers.Dense(input_shape=(512,),activation='relu', 
                           units=512, kernel_regularizer=keras.regularizers.l2(l=0.001)))

# %%
FCN.add(keras.layers.Dense(activation='relu', 
                           units=128, kernel_regularizer=keras.regularizers.l2(l=0.001)))

# %%
FCN.add(keras.layers.Dense(activation='softmax', 
                           units=12))

# %%
FCN.compile(loss=keras.losses.categorical_crossentropy, optimizer=keras.optimizers.Adam(), metrics=['accuracy'])

# %%
#FCN.fit(train_vgg_bf,one_hot_labels, epochs=30, validation_data=(valid_vgg_bf,valid_labels))
FCN.fit(train_vgg_bf,one_hot_labels, epochs=30)
# Out:
# Epoch 1/30
# 918/918 [==============================] - 0s 342us/step - loss: 0.1443 - acc: 0.9739
# Epoch 2/30
# 918/918 [==============================] - 0s 127us/step - loss: 0.1227 - acc: 0.9847
# Epoch 3/30
# 918/918 [==============================] - 0s 132us/step - loss: 0.0813 - acc: 0.9978
# Epoch 4/30
# 918/918 [==============================] - 0s 128us/step - loss: 0.0732 - acc: 1.0000
# Epoch 5/30
# 918/918 [==============================] - 0s 133us/step - loss: 0.0690 - acc: 1.0000
# Epoch 6/30
# 918/918 [==============================] - 0s 128us/step - loss: 0.0665 - acc: 1.0000
# Epoch 7/30
# 918/918 [==============================] - 0s 127us/step - loss: 0.0645 - acc: 1.0000
# Epoch 8/30
# 918/918 [==============================] - 0s 130us/step - loss: 0.0627 - acc: 1.0000
# Epoch 9/30
# 918/918 [==============================] - 0s 125us/step - loss: 0.0611 - acc: 1.0000
# Epoch 10/30
# 918/918 [==============================] - 0s 141us/step - loss: 0.0596 - acc: 1.0000
# Epoch 11/30
# 918/918 [==============================] - 0s 127us/step - loss: 0.0583 - acc: 1.0000
# Epoch 12/30
# 918/918 [==============================] - 0s 133us/step - loss: 0.0569 - acc: 1.0000
# Epoch 13/30
# 918/918 [==============================] - 0s 128us/step - loss: 0.0557 - acc: 1.0000
# Epoch 14/30
# 918/918 [==============================] - 0s 132us/step - loss: 0.0544 - acc: 1.0000
# Epoch 15/30
# 918/918 [==============================] - 0s 135us/step - loss: 0.0536 - acc: 1.0000
# Epoch 16/30
# 918/918 [==============================] - 0s 126us/step - loss: 0.0526 - acc: 1.0000
# Epoch 17/30
# 918/918 [==============================] - 0s 134us/step - loss: 0.0526 - acc: 1.0000
# Epoch 18/30
# 918/918 [==============================] - 0s 128us/step - loss: 0.0514 - acc: 1.0000
# Epoch 19/30
# 918/918 [==============================] - 0s 128us/step - loss: 0.0506 - acc: 1.0000
# Epoch 20/30
# 918/918 [==============================] - 0s 128us/step - loss: 0.0531 - acc: 1.0000
# Epoch 21/30
# 918/918 [==============================] - 0s 138us/step - loss: 0.3024 - acc: 0.9325
# Epoch 22/30
# 918/918 [==============================] - 0s 118us/step - loss: 0.3263 - acc: 0.9063
# Epoch 23/30
# 918/918 [==============================] - 0s 125us/step - loss: 0.2805 - acc: 0.9499
# Epoch 24/30
# 918/918 [==============================] - 0s 127us/step - loss: 0.1661 - acc: 0.9760
# Epoch 25/30
# 918/918 [==============================] - 0s 133us/step - loss: 0.1109 - acc: 0.9935
# Epoch 26/30
# 918/918 [==============================] - 0s 124us/step - loss: 0.0935 - acc: 1.0000
# Epoch 27/30
# 918/918 [==============================] - 0s 134us/step - loss: 0.0858 - acc: 1.0000
# Epoch 28/30
# 918/918 [==============================] - 0s 126us/step - loss: 0.0820 - acc: 1.0000
# Epoch 29/30
# 918/918 [==============================] - 0s 120us/step - loss: 0.0788 - acc: 1.0000
# Epoch 30/30
# 918/918 [==============================] - 0s 114us/step - loss: 0.0762 - acc: 1.0000

# %%
score = FCN.evaluate(valid_vgg_bf, valid_labels)
# Out:
# 282/282 [==============================] - 0s 239us/step

# %%
FCN.metrics_names
# Out:
# ['loss', 'acc']

# %%
score
# Out:
# [1.1436040688913764, 0.7730496462355269]

# %% [markdown]
# # Create submission

# %%
x_test = np.zeros((len(test), INPUT_SIZE, INPUT_SIZE, 3), dtype='float32')
for i, file in tqdm(enumerate(test['file_path'])):
    img = read_img(os.path.join(data_dir,file), (INPUT_SIZE, INPUT_SIZE))
    x = preprocess_input(np.expand_dims(img.copy(), axis=0))
    x_test[i] = x
print('test Images shape: {} size: {:,}'.format(x_test.shape, x_test.size))
# Out:
# 794it [00:02, 297.66it/s]
# test Images shape: (794, 224, 224, 3) size: 119,519,232

# %%
test_x_bf = vgg_bottleneck.predict(x_test, batch_size=32, verbose=1)
print('Test bottleneck features shape: {} size: {:,}'.format(test_x_bf.shape, test_x_bf.size))
# Out:
# 794/794 [==============================] - 2s 3ms/step
# Test bottleneck features shape: (794, 512) size: 406,528

# %%
test_preds = FCN.predict(test_x_bf)

# %%
np.argmax(test_preds,axis=1).shape
# Out:
# (794,)

# %%
test_pred_one = np.argmax(test_preds,axis=1)
test['category_id'] = test_pred_one
test['species'] = [CATEGORIES[c] for c in test_pred_one]
test[['file', 'species']].to_csv('submission.csv', index=False)
