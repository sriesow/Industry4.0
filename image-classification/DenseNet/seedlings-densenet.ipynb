# %%
import pandas as pd
import numpy as np
import random
import shutil
import os

from keras.applications import xception
from keras.optimizers import adam, SGD, rmsprop
from keras.models import Model
from keras.layers import Input, merge, ZeroPadding2D, Concatenate, concatenate
from keras.layers.core import Layer, Dense, Dropout, Activation
from keras.layers.convolutional import Conv2D
from keras.layers.pooling import AveragePooling2D, GlobalAveragePooling2D, MaxPooling2D
from keras.layers.normalization import BatchNormalization
from keras.regularizers import l2

from keras.callbacks import ReduceLROnPlateau, ModelCheckpoint, EarlyStopping, Callback, LearningRateScheduler

from keras.engine import InputSpec
from keras import initializers as initializations

from keras.preprocessing import image
from keras.preprocessing.image import ImageDataGenerator

import keras.backend as K
# Out:
# Using TensorFlow backend.

# %%
model_name = "DenseNet-161"
# model_name = "Xception"

data_set_path = "../plant-seedlings/"

categories = ['Black-grass', 'Charlock', 'Cleavers', 'Common Chickweed', 'Common wheat', 'Fat Hen', 'Loose Silky-bent',
              'Maize', 'Scentless Mayweed', 'Shepherds Purse', 'Small-flowered Cranesbill', 'Sugar beet']
num_categories = len(categories)
print("Categories : {}".format(num_categories))
# Out:
# Categories : 12

# %%
lr = 2e-4  # 8e-4
batch_size = 8
num_epochs = 200
pre_train_epochs = 20
num_steps_per_epoch = 300
img_rows, img_cols, img_channel = 224, 224, 3

num_snapshots = 6  # for ensemble

# %%
class SnapshotModelCheckpoint(Callback):
    """
    Callback that saves the snapshot weights of the model.
    Saves the model weights on certain epochs (which can be considered the
    snapshot of the model at that epoch).
    Should be used with the cosine annealing learning rate schedule to save
    the weight just before learning rate is sharply increased.
    # Arguments:
        nb_epochs: total number of epochs that the model will be trained for.
        nb_snapshots: number of times the weights of the model will be saved.
        fn_prefix: prefix for the filename of the weights.
    """

    def __init__(self, nb_epochs, nb_snapshots, fn_prefix='Model'):
        super(SnapshotModelCheckpoint, self).__init__()

        self.check = nb_epochs // nb_snapshots
        self.fn_prefix = fn_prefix

    def on_epoch_end(self, epoch, logs={}):
        if not epoch == 0 and (epoch + 1) % self.check == 0:
            file_path = "./checkpoints/" + self.fn_prefix + "-%d.h5" % ((epoch + 1) // self.check)
            # self.model.save_weights(file_path, overwrite=True)  # disable this code

            print("[*] Saved snapshot at ./checkpoints/%s_%d.h5" % (self.fn_prefix, (epoch + 1) // self.check))

# %%
class SnapshotCallbackBuilder:
    """
    Callback builder for snapshot ensemble training of a model.
    Creates a list of callbacks, which are provided when training a model
    so as to save the model weights at certain epochs, and then sharply
    increase the learning rate.
    """

    def __init__(self, nb_epochs, nb_snapshots, init_lr=1e-3):
        """
        Initialize a snapshot callback builder.
        # Arguments:
            nb_epochs: total number of epochs that the model will be trained for.
            nb_snapshots: number of times the weights of the model will be saved.
            init_lr: initial learning rate
        """
        self.T = nb_epochs
        self.M = nb_snapshots
        self.alpha_zero = init_lr

    def get_callbacks(self, model_prefix='Model'):
        """
        Creates a list of callbacks that can be used during training to create a
        snapshot ensemble of the model.
        Args:
            model_prefix: prefix for the filename of the weights.
        Returns: list of 3 callbacks [ModelCheckpoint, LearningRateScheduler,
                 SnapshotModelCheckpoint] which can be provided to the 'fit' function
        """

        callback_list = [ModelCheckpoint(filepath="./checkpoints/%s_acc-best.h5" % model_prefix,
                                         monitor="val_acc", save_best_only=True, save_weights_only=True, verbose=1),
                         LearningRateScheduler(schedule=self._cosine_anneal_schedule),
                         # LearningRateScheduler(schedule=lr_schedule),
                         # ReduceLROnPlateau(monitor='val_loss',
                         #                   patience=12, factor=0.75, cooldown=10, min_lr=1e-5, verbose=1),
                         EarlyStopping('val_loss', patience=30, verbose=1),
                         SnapshotModelCheckpoint(self.T, self.M, fn_prefix='%s' % model_prefix)]

        return callback_list

    def _cosine_anneal_schedule(self, t):
        cos_inner = np.pi * (t % (self.T // self.M))  # t - 1 is used when t has 1-based indexing.
        cos_inner /= self.T // self.M
        cos_out = np.cos(cos_inner) + 1

        return float(self.alpha_zero / 2 * cos_out)

# %%
class Scale(Layer):
    """
    Learns a set of weights and biases used for scaling the input data.
    the output consists simply in an element-wise multiplication of the input
    and a sum of a set of constants:
        out = in * gamma + beta,
    where 'gamma' and 'beta' are the weights and biases larned.
    # Arguments
        axis: integer, axis along which to normalize in mode 0. For instance,
            if your input tensor has shape (samples, channels, rows, cols),
            set axis to 1 to normalize per feature map (channels axis).
        momentum: momentum in the computation of the
            exponential average of the mean and standard deviation
            of the data, for feature-wise normalization.
        weights: Initialization weights.
            List of 2 Numpy arrays, with shapes:
            `[(input_shape,), (input_shape,)]`
        beta_init: name of initialization function for shift parameter
            (see [initializations](../initializations.md)), or alternatively,
            Theano/TensorFlow function to use for weights initialization.
            This parameter is only relevant if you don't pass a `weights` argument.
        gamma_init: name of initialization function for scale parameter (see
            [initializations](../initializations.md)), or alternatively,
            Theano/TensorFlow function to use for weights initialization.
            This parameter is only relevant if you don't pass a `weights` argument.
    """

    def __init__(self, weights=None, axis=-1, momentum = 0.9, beta_init='zero', gamma_init='one', **kwargs):
        self.momentum = momentum
        self.axis = axis
        self.beta_init = initializations.get(beta_init)
        self.gamma_init = initializations.get(gamma_init)
        self.initial_weights = weights

        super(Scale, self).__init__(**kwargs)

    def build(self, input_shape):
        self.input_spec = [InputSpec(shape=input_shape)]
        shape = (int(input_shape[self.axis]),)

        # Compatibility with TensorFlow >= 1.0.0
        self.gamma = K.variable(self.gamma_init(shape), name='{}_gamma'.format(self.name))
        self.beta = K.variable(self.beta_init(shape), name='{}_beta'.format(self.name))
        # self.gamma = self.gamma_init(shape, name='{}_gamma'.format(self.name))
        # self.beta = self.beta_init(shape, name='{}_beta'.format(self.name))
        self.trainable_weights = [self.gamma, self.beta]

        if self.initial_weights is not None:
            self.set_weights(self.initial_weights)
            del self.initial_weights

    def call(self, x, mask=None):
        input_shape = self.input_spec[0].shape
        broadcast_shape = [1] * len(input_shape)
        broadcast_shape[self.axis] = input_shape[self.axis]

        out = K.reshape(self.gamma, broadcast_shape) * x + K.reshape(self.beta, broadcast_shape)
        return out

    def get_config(self):
        config = {"momentum": self.momentum, "axis": self.axis}
        base_config = super(Scale, self).get_config()

        return dict(list(base_config.items()) + list(config.items()))

# %%
def densenet161_model(img_rows, img_cols, color_type=1, nb_dense_block=4, growth_rate=48, nb_filter=96, reduction=0.5,
                      dropout_rate=0.0, weight_decay=1e-4, num_classes=None, lr=8e-4):
    """
    DenseNet 161 Model for Keras
    Model Schema is based on
    https://github.com/flyyufelix/DenseNet-Keras
    ImageNet Pretrained Weights
    Theano: https://drive.google.com/open?id=0Byy2AcGyEVxfVnlCMlBGTDR3RGs
    TensorFlow: https://drive.google.com/open?id=0Byy2AcGyEVxfUDZwVjU2cFNidTA
    # Arguments
        nb_dense_block: number of dense blocks to add to end
        growth_rate: number of filters to add per dense block
        nb_filter: initial number of filters
        reduction: reduction factor of transition blocks.
        dropout_rate: dropout rate
        weight_decay: weight decay factor
        classes: optional number of classes to classify images
        weights_path: path to pre-trained weights
    # Returns
        A Keras model instance.
    """

    eps = 1.1e-5

    # compute compression factor
    compression = 1.0 - reduction

    # Handle Dimension Ordering for different backends
    global concat_axis

    concat_axis = 3
    img_input = Input(shape=(img_rows, img_cols, 3), name='data')

    # From architecture for ImageNet (Table 1 in the paper)
    nb_filter = 96
    nb_layers = [6, 12, 36, 24]  # For DenseNet-161

    # Initial convolution
    x = ZeroPadding2D((3, 3), name='conv1_zeropadding')(img_input)
    x = Conv2D(nb_filter, (7, 7), strides=(2, 2), name='conv1', use_bias=False)(x)
    x = BatchNormalization(epsilon=eps, axis=concat_axis, name='conv1_bn')(x)
    x = Scale(axis=concat_axis, name='conv1_scale')(x)
    x = Activation('relu', name='relu1')(x)
    x = ZeroPadding2D((1, 1), name='pool1_zeropadding')(x)
    x = MaxPooling2D((3, 3), strides=(2, 2), name='pool1')(x)

    # Add dense blocks
    for block_idx in range(nb_dense_block - 1):
        stage = block_idx+2
        x, nb_filter = dense_block(x, stage, nb_layers[block_idx], nb_filter, growth_rate, dropout_rate=dropout_rate,
                                   weight_decay=weight_decay)

        # Add transition_block
        x = transition_block(x, stage, nb_filter, compression=compression, dropout_rate=dropout_rate,
                             weight_decay=weight_decay)
        nb_filter = int(nb_filter * compression)

    final_stage = stage + 1
    x, nb_filter = dense_block(x, final_stage, nb_layers[-1], nb_filter, growth_rate, dropout_rate=dropout_rate,
                               weight_decay=weight_decay)

    x = BatchNormalization(epsilon=eps, axis=concat_axis, name='conv'+str(final_stage)+'_blk_bn')(x)
    x = Scale(axis=concat_axis, name='conv'+str(final_stage)+'_blk_scale')(x)
    x = Activation('relu', name='relu'+str(final_stage)+'_blk')(x)

    # x_fc = GlobalAveragePooling2D(name='pool'+str(final_stage))(x)
    # x_fc = Dense(1000, name='fc6')(x_fc)
    # x_fc = Activation('softmax', name='prob')(x_fc)

    model = Model(img_input, x, name='densenet')

    # weight path
    weights_path = './models/densenet161_weights_tf.h5'

    model.load_weights(weights_path, by_name=True)

    # Truncate and replace softmax layer for transfer learning
    # Cannot use model.layers.pop() since model is not of Sequential() type
    # The method below works since pre-trained weights are stored in layers but not in the model
    x_newfc = GlobalAveragePooling2D(name='pool'+str(final_stage))(x)
    x_newfc = Dense(num_classes, name='fc6')(x_newfc)
    x_newfc = Activation('softmax', name='prob')(x_newfc)

    model = Model(img_input, x_newfc)

    # Learning rate is changed to 0.001
    sgd = SGD(lr=lr, decay=1e-6, momentum=0.9, nesterov=True)
    model.compile(optimizer=sgd, loss='categorical_crossentropy', metrics=['accuracy'])

    return model

# %%
def conv_block(x, stage, branch, nb_filter, dropout_rate=None, weight_decay=1e-4):
    """
    Apply BatchNorm, Relu, bottleneck 1x1 Conv2D, 3x3 Conv2D, and option dropout
        # Arguments
            x: input tensor
            stage: index for dense block
            branch: layer index within each dense block
            nb_filter: number of filters
            dropout_rate: dropout rate
            weight_decay: weight decay factor
    """

    eps = 1.1e-5
    conv_name_base = 'conv' + str(stage) + '_' + str(branch)
    relu_name_base = 'relu' + str(stage) + '_' + str(branch)

    # 1x1 Convolution (Bottleneck layer)
    inter_channel = nb_filter * 4
    x = BatchNormalization(epsilon=eps, axis=concat_axis, name=conv_name_base+'_x1_bn')(x)
    x = Scale(axis=concat_axis, name=conv_name_base+'_x1_scale')(x)
    x = Activation('relu', name=relu_name_base+'_x1')(x)
    x = Conv2D(inter_channel, (1, 1), name=conv_name_base+'_x1', use_bias=False)(x)

    if dropout_rate:
        x = Dropout(dropout_rate)(x)

    # 3x3 Convolution
    x = BatchNormalization(epsilon=eps, axis=concat_axis, name=conv_name_base+'_x2_bn')(x)
    x = Scale(axis=concat_axis, name=conv_name_base+'_x2_scale')(x)
    x = Activation('relu', name=relu_name_base+'_x2')(x)
    x = ZeroPadding2D((1, 1), name=conv_name_base+'_x2_zeropadding')(x)
    x = Conv2D(nb_filter, (3, 3), name=conv_name_base+'_x2', use_bias=False)(x)

    if dropout_rate:
        x = Dropout(dropout_rate)(x)

    return x

# %%
def transition_block(x, stage, nb_filter, compression=1.0, dropout_rate=None, weight_decay=1e-4):
    """
    Apply BatchNorm, 1x1 Convolution, averagePooling, optional compression, dropout
        # Arguments
            x: input tensor
            stage: index for dense block
            nb_filter: number of filters
            compression: calculated as 1 - reduction. Reduces the number of feature maps in the transition block.
            dropout_rate: dropout rate
            weight_decay: weight decay factor
    """

    eps = 1.1e-5
    conv_name_base = 'conv' + str(stage) + '_blk'
    relu_name_base = 'relu' + str(stage) + '_blk'
    pool_name_base = 'pool' + str(stage)

    x = BatchNormalization(epsilon=eps, axis=concat_axis, name=conv_name_base+'_bn')(x)
    x = Scale(axis=concat_axis, name=conv_name_base+'_scale')(x)
    x = Activation('relu', name=relu_name_base)(x)
    x = Conv2D(int(nb_filter * compression), (1, 1), name=conv_name_base, use_bias=False)(x)

    if dropout_rate:
        x = Dropout(dropout_rate)(x)

    x = AveragePooling2D((2, 2), strides=(2, 2), name=pool_name_base)(x)

    return x

# %%
def dense_block(x, stage, nb_layers, nb_filter, growth_rate, dropout_rate=None, weight_decay=1e-4,
                grow_nb_filters=True):
    """
    Build a dense_block where the output of each conv_block is fed to subsequent ones
        # Arguments
            x: input tensor
            stage: index for dense block
            nb_layers: the number of layers of conv_block to append to the model.
            nb_filter: number of filters
            growth_rate: growth rate
            dropout_rate: dropout rate
            weight_decay: weight decay factor
            grow_nb_filters: flag to decide to allow number of filters to grow
    """

    eps = 1.1e-5
    concat_feat = x

    for i in range(nb_layers):
        branch = i + 1
        x = conv_block(concat_feat, stage, branch, growth_rate, dropout_rate, weight_decay)
        #concat_feat = merge([concat_feat, x], mode='concat', concat_axis=concat_axis,
        #                    name='concat_' + str(stage) + '_' + str(branch))
        #concat_feat = Concatenate(axis=1)([concat_feat, x])
        concat_feat = concatenate([concat_feat, x], axis=concat_axis)

        if grow_nb_filters:
            nb_filter += growth_rate

    return concat_feat, nb_filter

# %%
def split_val_data(split_rate=0.2):
    val_path = data_set_path + "val/"
    train_path = data_set_path + "train/"

    if os.path.exists(val_path):
        return False
    else:
        # make validation data set path
        os.mkdir(val_path)

        for cat in categories:
            os.mkdir(val_path + cat)

            train_path_name = os.listdir(train_path + cat)
            # shuffling files
            random.shuffle(train_path_name)

            # split data set
            to_val = train_path_name[:int(len(train_path_name) * split_rate)]

            for f in to_val:
                shutil.move(os.path.join(train_path, cat, f), os.path.join(val_path, cat))

        return True


def read_img(file_path, size=(img_rows, img_cols), data_dir=data_set_path):
    img = image.load_img(os.path.join(data_dir, file_path), target_size=size)
    img = image.img_to_array(img)

    return img

# %%
# split train/val data
split_data = False  # just done with once at initial time
if split_data:
    split_val_data()

# %%
# Callbacks
snapshot = SnapshotCallbackBuilder(num_epochs, num_snapshots, lr)

# %%
train_data_gen = ImageDataGenerator(
    rescale=1. / 255,
    rotation_range=60,
    width_shift_range=0.30,
    height_shift_range=0.30,
    shear_range=0.25,
    zoom_range=0.25,
    horizontal_flip=True,
    vertical_flip=True,
    fill_mode='nearest')
train_generator = train_data_gen.flow_from_directory(
    directory=data_set_path + "train/",
    target_size=(img_cols, img_rows),
    batch_size=batch_size,
    class_mode='categorical',
    shuffle=True
)

val_data_gen = ImageDataGenerator(
    rescale=1. / 225,
)
val_generator = val_data_gen.flow_from_directory(
    directory=data_set_path + "val/",
    target_size=(img_cols, img_rows),
    batch_size=batch_size,
    class_mode='categorical',
    shuffle=True
)
# Out:
# Found 3803 images belonging to 12 classes.
# Found 947 images belonging to 12 classes.

# %%
# building model
model = densenet161_model(img_rows=img_rows, img_cols=img_cols, color_type=img_channel, num_classes=num_categories,
                          lr=lr)
# base_model = xception.Xception(include_top=False, weights='imagenet',
#                                input_shape=(img_rows, img_cols, img_channel), pooling='avg')

"""
x = base_model.output
x = Dropout(.5)(x)
x = Dense(num_categories, activation='softmax')(x)

model = Model(inputs=base_model.input, outputs=x)
"""
# Out:
# "\nx = base_model.output\nx = Dropout(.5)(x)\nx = Dense(num_categories, activation='softmax')(x)\n\nmodel = Model(inputs=base_model.input, outputs=x)\n"

# %%
# print model summary
model.summary()
# Out:
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# data (InputLayer)               (None, 224, 224, 3)  0
# __________________________________________________________________________________________________
# conv1_zeropadding (ZeroPadding2 (None, 230, 230, 3)  0           data[0][0]
# __________________________________________________________________________________________________
# conv1 (Conv2D)                  (None, 112, 112, 96) 14112       conv1_zeropadding[0][0]
# __________________________________________________________________________________________________
# conv1_bn (BatchNormalization)   (None, 112, 112, 96) 384         conv1[0][0]
# __________________________________________________________________________________________________
# conv1_scale (Scale)             (None, 112, 112, 96) 192         conv1_bn[0][0]
# __________________________________________________________________________________________________
# relu1 (Activation)              (None, 112, 112, 96) 0           conv1_scale[0][0]
# __________________________________________________________________________________________________
# pool1_zeropadding (ZeroPadding2 (None, 114, 114, 96) 0           relu1[0][0]
# __________________________________________________________________________________________________
# pool1 (MaxPooling2D)            (None, 56, 56, 96)   0           pool1_zeropadding[0][0]
# __________________________________________________________________________________________________
# conv2_1_x1_bn (BatchNormalizati (None, 56, 56, 96)   384         pool1[0][0]
# __________________________________________________________________________________________________
# conv2_1_x1_scale (Scale)        (None, 56, 56, 96)   192         conv2_1_x1_bn[0][0]
# __________________________________________________________________________________________________
# relu2_1_x1 (Activation)         (None, 56, 56, 96)   0           conv2_1_x1_scale[0][0]
# __________________________________________________________________________________________________
# conv2_1_x1 (Conv2D)             (None, 56, 56, 192)  18432       relu2_1_x1[0][0]
# __________________________________________________________________________________________________
# conv2_1_x2_bn (BatchNormalizati (None, 56, 56, 192)  768         conv2_1_x1[0][0]
# __________________________________________________________________________________________________
# conv2_1_x2_scale (Scale)        (None, 56, 56, 192)  384         conv2_1_x2_bn[0][0]
# __________________________________________________________________________________________________
# relu2_1_x2 (Activation)         (None, 56, 56, 192)  0           conv2_1_x2_scale[0][0]
# __________________________________________________________________________________________________
# conv2_1_x2_zeropadding (ZeroPad (None, 58, 58, 192)  0           relu2_1_x2[0][0]
# __________________________________________________________________________________________________
# conv2_1_x2 (Conv2D)             (None, 56, 56, 48)   82944       conv2_1_x2_zeropadding[0][0]
# __________________________________________________________________________________________________
# concatenate_1 (Concatenate)     (None, 56, 56, 144)  0           pool1[0][0]
#                                                                  conv2_1_x2[0][0]
# __________________________________________________________________________________________________
# conv2_2_x1_bn (BatchNormalizati (None, 56, 56, 144)  576         concatenate_1[0][0]
# __________________________________________________________________________________________________
# conv2_2_x1_scale (Scale)        (None, 56, 56, 144)  288         conv2_2_x1_bn[0][0]
# __________________________________________________________________________________________________
# relu2_2_x1 (Activation)         (None, 56, 56, 144)  0           conv2_2_x1_scale[0][0]
# __________________________________________________________________________________________________
# conv2_2_x1 (Conv2D)             (None, 56, 56, 192)  27648       relu2_2_x1[0][0]
# __________________________________________________________________________________________________
# conv2_2_x2_bn (BatchNormalizati (None, 56, 56, 192)  768         conv2_2_x1[0][0]
# __________________________________________________________________________________________________
# conv2_2_x2_scale (Scale)        (None, 56, 56, 192)  384         conv2_2_x2_bn[0][0]
# __________________________________________________________________________________________________
# relu2_2_x2 (Activation)         (None, 56, 56, 192)  0           conv2_2_x2_scale[0][0]
# __________________________________________________________________________________________________
# conv2_2_x2_zeropadding (ZeroPad (None, 58, 58, 192)  0           relu2_2_x2[0][0]
# __________________________________________________________________________________________________
# conv2_2_x2 (Conv2D)             (None, 56, 56, 48)   82944       conv2_2_x2_zeropadding[0][0]
# __________________________________________________________________________________________________
# concatenate_2 (Concatenate)     (None, 56, 56, 192)  0           concatenate_1[0][0]
#                                                                  conv2_2_x2[0][0]
# __________________________________________________________________________________________________
# conv2_3_x1_bn (BatchNormalizati (None, 56, 56, 192)  768         concatenate_2[0][0]
# __________________________________________________________________________________________________
# conv2_3_x1_scale (Scale)        (None, 56, 56, 192)  384         conv2_3_x1_bn[0][0]
# __________________________________________________________________________________________________
# relu2_3_x1 (Activation)         (None, 56, 56, 192)  0           conv2_3_x1_scale[0][0]
# __________________________________________________________________________________________________
# conv2_3_x1 (Conv2D)             (None, 56, 56, 192)  36864       relu2_3_x1[0][0]
# __________________________________________________________________________________________________
# conv2_3_x2_bn (BatchNormalizati (None, 56, 56, 192)  768         conv2_3_x1[0][0]
# __________________________________________________________________________________________________
# conv2_3_x2_scale (Scale)        (None, 56, 56, 192)  384         conv2_3_x2_bn[0][0]
# __________________________________________________________________________________________________
# relu2_3_x2 (Activation)         (None, 56, 56, 192)  0           conv2_3_x2_scale[0][0]
# __________________________________________________________________________________________________
# conv2_3_x2_zeropadding (ZeroPad (None, 58, 58, 192)  0           relu2_3_x2[0][0]
# __________________________________________________________________________________________________
# conv2_3_x2 (Conv2D)             (None, 56, 56, 48)   82944       conv2_3_x2_zeropadding[0][0]
# __________________________________________________________________________________________________
# concatenate_3 (Concatenate)     (None, 56, 56, 240)  0           concatenate_2[0][0]
#                                                                  conv2_3_x2[0][0]
# __________________________________________________________________________________________________
# conv2_4_x1_bn (BatchNormalizati (None, 56, 56, 240)  960         concatenate_3[0][0]
# __________________________________________________________________________________________________
# conv2_4_x1_scale (Scale)        (None, 56, 56, 240)  480         conv2_4_x1_bn[0][0]
# __________________________________________________________________________________________________
# relu2_4_x1 (Activation)         (None, 56, 56, 240)  0           conv2_4_x1_scale[0][0]
# __________________________________________________________________________________________________
# conv2_4_x1 (Conv2D)             (None, 56, 56, 192)  46080       relu2_4_x1[0][0]
# __________________________________________________________________________________________________
# conv2_4_x2_bn (BatchNormalizati (None, 56, 56, 192)  768         conv2_4_x1[0][0]
# __________________________________________________________________________________________________
# conv2_4_x2_scale (Scale)        (None, 56, 56, 192)  384         conv2_4_x2_bn[0][0]
# __________________________________________________________________________________________________
# relu2_4_x2 (Activation)         (None, 56, 56, 192)  0           conv2_4_x2_scale[0][0]
# __________________________________________________________________________________________________
# conv2_4_x2_zeropadding (ZeroPad (None, 58, 58, 192)  0           relu2_4_x2[0][0]
# __________________________________________________________________________________________________
# conv2_4_x2 (Conv2D)             (None, 56, 56, 48)   82944       conv2_4_x2_zeropadding[0][0]
# __________________________________________________________________________________________________
# concatenate_4 (Concatenate)     (None, 56, 56, 288)  0           concatenate_3[0][0]
#                                                                  conv2_4_x2[0][0]
# __________________________________________________________________________________________________
# conv2_5_x1_bn (BatchNormalizati (None, 56, 56, 288)  1152        concatenate_4[0][0]
# __________________________________________________________________________________________________
# conv2_5_x1_scale (Scale)        (None, 56, 56, 288)  576         conv2_5_x1_bn[0][0]
# __________________________________________________________________________________________________
# relu2_5_x1 (Activation)         (None, 56, 56, 288)  0           conv2_5_x1_scale[0][0]
# __________________________________________________________________________________________________
# conv2_5_x1 (Conv2D)             (None, 56, 56, 192)  55296       relu2_5_x1[0][0]
# __________________________________________________________________________________________________
# conv2_5_x2_bn (BatchNormalizati (None, 56, 56, 192)  768         conv2_5_x1[0][0]
# __________________________________________________________________________________________________
# conv2_5_x2_scale (Scale)        (None, 56, 56, 192)  384         conv2_5_x2_bn[0][0]
# __________________________________________________________________________________________________
# relu2_5_x2 (Activation)         (None, 56, 56, 192)  0           conv2_5_x2_scale[0][0]
# __________________________________________________________________________________________________
# conv2_5_x2_zeropadding (ZeroPad (None, 58, 58, 192)  0           relu2_5_x2[0][0]
# __________________________________________________________________________________________________
# conv2_5_x2 (Conv2D)             (None, 56, 56, 48)   82944       conv2_5_x2_zeropadding[0][0]
# __________________________________________________________________________________________________
# concatenate_5 (Concatenate)     (None, 56, 56, 336)  0           concatenate_4[0][0]
#                                                                  conv2_5_x2[0][0]
# __________________________________________________________________________________________________
# conv2_6_x1_bn (BatchNormalizati (None, 56, 56, 336)  1344        concatenate_5[0][0]
# __________________________________________________________________________________________________
# conv2_6_x1_scale (Scale)        (None, 56, 56, 336)  672         conv2_6_x1_bn[0][0]
# __________________________________________________________________________________________________
# relu2_6_x1 (Activation)         (None, 56, 56, 336)  0           conv2_6_x1_scale[0][0]
# __________________________________________________________________________________________________
# conv2_6_x1 (Conv2D)             (None, 56, 56, 192)  64512       relu2_6_x1[0][0]
# __________________________________________________________________________________________________
# conv2_6_x2_bn (BatchNormalizati (None, 56, 56, 192)  768         conv2_6_x1[0][0]
# __________________________________________________________________________________________________
# conv2_6_x2_scale (Scale)        (None, 56, 56, 192)  384         conv2_6_x2_bn[0][0]
# __________________________________________________________________________________________________
# relu2_6_x2 (Activation)         (None, 56, 56, 192)  0           conv2_6_x2_scale[0][0]
# __________________________________________________________________________________________________
# conv2_6_x2_zeropadding (ZeroPad (None, 58, 58, 192)  0           relu2_6_x2[0][0]
# __________________________________________________________________________________________________
# conv2_6_x2 (Conv2D)             (None, 56, 56, 48)   82944       conv2_6_x2_zeropadding[0][0]
# __________________________________________________________________________________________________
# concatenate_6 (Concatenate)     (None, 56, 56, 384)  0           concatenate_5[0][0]
#                                                                  conv2_6_x2[0][0]
# __________________________________________________________________________________________________
# conv2_blk_bn (BatchNormalizatio (None, 56, 56, 384)  1536        concatenate_6[0][0]
# __________________________________________________________________________________________________
# conv2_blk_scale (Scale)         (None, 56, 56, 384)  768         conv2_blk_bn[0][0]
# __________________________________________________________________________________________________
# relu2_blk (Activation)          (None, 56, 56, 384)  0           conv2_blk_scale[0][0]
# __________________________________________________________________________________________________
# conv2_blk (Conv2D)              (None, 56, 56, 192)  73728       relu2_blk[0][0]
# __________________________________________________________________________________________________
# pool2 (AveragePooling2D)        (None, 28, 28, 192)  0           conv2_blk[0][0]
# __________________________________________________________________________________________________
# conv3_1_x1_bn (BatchNormalizati (None, 28, 28, 192)  768         pool2[0][0]
# __________________________________________________________________________________________________
# conv3_1_x1_scale (Scale)        (None, 28, 28, 192)  384         conv3_1_x1_bn[0][0]
# __________________________________________________________________________________________________
# relu3_1_x1 (Activation)         (None, 28, 28, 192)  0           conv3_1_x1_scale[0][0]
# __________________________________________________________________________________________________
# conv3_1_x1 (Conv2D)             (None, 28, 28, 192)  36864       relu3_1_x1[0][0]
# __________________________________________________________________________________________________
# conv3_1_x2_bn (BatchNormalizati (None, 28, 28, 192)  768         conv3_1_x1[0][0]
# __________________________________________________________________________________________________
# conv3_1_x2_scale (Scale)        (None, 28, 28, 192)  384         conv3_1_x2_bn[0][0]
# __________________________________________________________________________________________________
# relu3_1_x2 (Activation)         (None, 28, 28, 192)  0           conv3_1_x2_scale[0][0]
# __________________________________________________________________________________________________
# conv3_1_x2_zeropadding (ZeroPad (None, 30, 30, 192)  0           relu3_1_x2[0][0]
# __________________________________________________________________________________________________
# conv3_1_x2 (Conv2D)             (None, 28, 28, 48)   82944       conv3_1_x2_zeropadding[0][0]
# __________________________________________________________________________________________________
# concatenate_7 (Concatenate)     (None, 28, 28, 240)  0           pool2[0][0]
#                                                                  conv3_1_x2[0][0]
# __________________________________________________________________________________________________
# conv3_2_x1_bn (BatchNormalizati (None, 28, 28, 240)  960         concatenate_7[0][0]
# __________________________________________________________________________________________________
# conv3_2_x1_scale (Scale)        (None, 28, 28, 240)  480         conv3_2_x1_bn[0][0]
# __________________________________________________________________________________________________
# relu3_2_x1 (Activation)         (None, 28, 28, 240)  0           conv3_2_x1_scale[0][0]
# __________________________________________________________________________________________________
# conv3_2_x1 (Conv2D)             (None, 28, 28, 192)  46080       relu3_2_x1[0][0]
# __________________________________________________________________________________________________
# conv3_2_x2_bn (BatchNormalizati (None, 28, 28, 192)  768         conv3_2_x1[0][0]
# __________________________________________________________________________________________________
# conv3_2_x2_scale (Scale)        (None, 28, 28, 192)  384         conv3_2_x2_bn[0][0]
# __________________________________________________________________________________________________
# relu3_2_x2 (Activation)         (None, 28, 28, 192)  0           conv3_2_x2_scale[0][0]
# __________________________________________________________________________________________________
# conv3_2_x2_zeropadding (ZeroPad (None, 30, 30, 192)  0           relu3_2_x2[0][0]
# __________________________________________________________________________________________________
# conv3_2_x2 (Conv2D)             (None, 28, 28, 48)   82944       conv3_2_x2_zeropadding[0][0]
# __________________________________________________________________________________________________
# concatenate_8 (Concatenate)     (None, 28, 28, 288)  0           concatenate_7[0][0]
#                                                                  conv3_2_x2[0][0]
# __________________________________________________________________________________________________
# conv3_3_x1_bn (BatchNormalizati (None, 28, 28, 288)  1152        concatenate_8[0][0]
# __________________________________________________________________________________________________
# conv3_3_x1_scale (Scale)        (None, 28, 28, 288)  576         conv3_3_x1_bn[0][0]
# __________________________________________________________________________________________________
# relu3_3_x1 (Activation)         (None, 28, 28, 288)  0           conv3_3_x1_scale[0][0]
# __________________________________________________________________________________________________
# conv3_3_x1 (Conv2D)             (None, 28, 28, 192)  55296       relu3_3_x1[0][0]
# __________________________________________________________________________________________________
# conv3_3_x2_bn (BatchNormalizati (None, 28, 28, 192)  768         conv3_3_x1[0][0]
# __________________________________________________________________________________________________
# conv3_3_x2_scale (Scale)        (None, 28, 28, 192)  384         conv3_3_x2_bn[0][0]
# __________________________________________________________________________________________________
# relu3_3_x2 (Activation)         (None, 28, 28, 192)  0           conv3_3_x2_scale[0][0]
# __________________________________________________________________________________________________
# conv3_3_x2_zeropadding (ZeroPad (None, 30, 30, 192)  0           relu3_3_x2[0][0]
# __________________________________________________________________________________________________
# conv3_3_x2 (Conv2D)             (None, 28, 28, 48)   82944       conv3_3_x2_zeropadding[0][0]
# __________________________________________________________________________________________________
# concatenate_9 (Concatenate)     (None, 28, 28, 336)  0           concatenate_8[0][0]
#                                                                  conv3_3_x2[0][0]
# __________________________________________________________________________________________________
# conv3_4_x1_bn (BatchNormalizati (None, 28, 28, 336)  1344        concatenate_9[0][0]
# __________________________________________________________________________________________________
# conv3_4_x1_scale (Scale)        (None, 28, 28, 336)  672         conv3_4_x1_bn[0][0]
# __________________________________________________________________________________________________
# relu3_4_x1 (Activation)         (None, 28, 28, 336)  0           conv3_4_x1_scale[0][0]
# __________________________________________________________________________________________________
# conv3_4_x1 (Conv2D)             (None, 28, 28, 192)  64512       relu3_4_x1[0][0]
# __________________________________________________________________________________________________
# conv3_4_x2_bn (BatchNormalizati (None, 28, 28, 192)  768         conv3_4_x1[0][0]
# __________________________________________________________________________________________________
# conv3_4_x2_scale (Scale)        (None, 28, 28, 192)  384         conv3_4_x2_bn[0][0]
# __________________________________________________________________________________________________
# relu3_4_x2 (Activation)         (None, 28, 28, 192)  0           conv3_4_x2_scale[0][0]
# __________________________________________________________________________________________________
# conv3_4_x2_zeropadding (ZeroPad (None, 30, 30, 192)  0           relu3_4_x2[0][0]
# __________________________________________________________________________________________________
# conv3_4_x2 (Conv2D)             (None, 28, 28, 48)   82944       conv3_4_x2_zeropadding[0][0]
# __________________________________________________________________________________________________
# concatenate_10 (Concatenate)    (None, 28, 28, 384)  0           concatenate_9[0][0]
#                                                                  conv3_4_x2[0][0]
# __________________________________________________________________________________________________
# conv3_5_x1_bn (BatchNormalizati (None, 28, 28, 384)  1536        concatenate_10[0][0]
# __________________________________________________________________________________________________
# conv3_5_x1_scale (Scale)        (None, 28, 28, 384)  768         conv3_5_x1_bn[0][0]
# __________________________________________________________________________________________________
# relu3_5_x1 (Activation)         (None, 28, 28, 384)  0           conv3_5_x1_scale[0][0]
# __________________________________________________________________________________________________
# conv3_5_x1 (Conv2D)             (None, 28, 28, 192)  73728       relu3_5_x1[0][0]
# __________________________________________________________________________________________________
# conv3_5_x2_bn (BatchNormalizati (None, 28, 28, 192)  768         conv3_5_x1[0][0]
# __________________________________________________________________________________________________
# conv3_5_x2_scale (Scale)        (None, 28, 28, 192)  384         conv3_5_x2_bn[0][0]
# __________________________________________________________________________________________________
# relu3_5_x2 (Activation)         (None, 28, 28, 192)  0           conv3_5_x2_scale[0][0]
# __________________________________________________________________________________________________
# conv3_5_x2_zeropadding (ZeroPad (None, 30, 30, 192)  0           relu3_5_x2[0][0]
# __________________________________________________________________________________________________
# conv3_5_x2 (Conv2D)             (None, 28, 28, 48)   82944       conv3_5_x2_zeropadding[0][0]
# __________________________________________________________________________________________________
# concatenate_11 (Concatenate)    (None, 28, 28, 432)  0           concatenate_10[0][0]
#                                                                  conv3_5_x2[0][0]
# __________________________________________________________________________________________________
# conv3_6_x1_bn (BatchNormalizati (None, 28, 28, 432)  1728        concatenate_11[0][0]
# __________________________________________________________________________________________________
# conv3_6_x1_scale (Scale)        (None, 28, 28, 432)  864         conv3_6_x1_bn[0][0]
# __________________________________________________________________________________________________
# relu3_6_x1 (Activation)         (None, 28, 28, 432)  0           conv3_6_x1_scale[0][0]
# __________________________________________________________________________________________________
# conv3_6_x1 (Conv2D)             (None, 28, 28, 192)  82944       relu3_6_x1[0][0]
# __________________________________________________________________________________________________
# conv3_6_x2_bn (BatchNormalizati (None, 28, 28, 192)  768         conv3_6_x1[0][0]
# __________________________________________________________________________________________________
# conv3_6_x2_scale (Scale)        (None, 28, 28, 192)  384         conv3_6_x2_bn[0][0]
# __________________________________________________________________________________________________
# relu3_6_x2 (Activation)         (None, 28, 28, 192)  0           conv3_6_x2_scale[0][0]
# __________________________________________________________________________________________________
# conv3_6_x2_zeropadding (ZeroPad (None, 30, 30, 192)  0           relu3_6_x2[0][0]
# __________________________________________________________________________________________________
# conv3_6_x2 (Conv2D)             (None, 28, 28, 48)   82944       conv3_6_x2_zeropadding[0][0]
# __________________________________________________________________________________________________
# concatenate_12 (Concatenate)    (None, 28, 28, 480)  0           concatenate_11[0][0]
#                                                                  conv3_6_x2[0][0]
# __________________________________________________________________________________________________
# conv3_7_x1_bn (BatchNormalizati (None, 28, 28, 480)  1920        concatenate_12[0][0]
# __________________________________________________________________________________________________
# conv3_7_x1_scale (Scale)        (None, 28, 28, 480)  960         conv3_7_x1_bn[0][0]
# __________________________________________________________________________________________________
# relu3_7_x1 (Activation)         (None, 28, 28, 480)  0           conv3_7_x1_scale[0][0]
# __________________________________________________________________________________________________
# conv3_7_x1 (Conv2D)             (None, 28, 28, 192)  92160       relu3_7_x1[0][0]
# __________________________________________________________________________________________________
# conv3_7_x2_bn (BatchNormalizati (None, 28, 28, 192)  768         conv3_7_x1[0][0]
# __________________________________________________________________________________________________
# conv3_7_x2_scale (Scale)        (None, 28, 28, 192)  384         conv3_7_x2_bn[0][0]
# __________________________________________________________________________________________________
# relu3_7_x2 (Activation)         (None, 28, 28, 192)  0           conv3_7_x2_scale[0][0]
# __________________________________________________________________________________________________
# conv3_7_x2_zeropadding (ZeroPad (None, 30, 30, 192)  0           relu3_7_x2[0][0]
# __________________________________________________________________________________________________
# conv3_7_x2 (Conv2D)             (None, 28, 28, 48)   82944       conv3_7_x2_zeropadding[0][0]
# __________________________________________________________________________________________________
# concatenate_13 (Concatenate)    (None, 28, 28, 528)  0           concatenate_12[0][0]
#                                                                  conv3_7_x2[0][0]
# __________________________________________________________________________________________________
# conv3_8_x1_bn (BatchNormalizati (None, 28, 28, 528)  2112        concatenate_13[0][0]
# __________________________________________________________________________________________________
# conv3_8_x1_scale (Scale)        (None, 28, 28, 528)  1056        conv3_8_x1_bn[0][0]
# __________________________________________________________________________________________________
# relu3_8_x1 (Activation)         (None, 28, 28, 528)  0           conv3_8_x1_scale[0][0]
# __________________________________________________________________________________________________
# conv3_8_x1 (Conv2D)             (None, 28, 28, 192)  101376      relu3_8_x1[0][0]
# __________________________________________________________________________________________________
# conv3_8_x2_bn (BatchNormalizati (None, 28, 28, 192)  768         conv3_8_x1[0][0]
# __________________________________________________________________________________________________
# conv3_8_x2_scale (Scale)        (None, 28, 28, 192)  384         conv3_8_x2_bn[0][0]
# __________________________________________________________________________________________________
# relu3_8_x2 (Activation)         (None, 28, 28, 192)  0           conv3_8_x2_scale[0][0]
# __________________________________________________________________________________________________
# conv3_8_x2_zeropadding (ZeroPad (None, 30, 30, 192)  0           relu3_8_x2[0][0]
# __________________________________________________________________________________________________
# conv3_8_x2 (Conv2D)             (None, 28, 28, 48)   82944       conv3_8_x2_zeropadding[0][0]
# __________________________________________________________________________________________________
# concatenate_14 (Concatenate)    (None, 28, 28, 576)  0           concatenate_13[0][0]
#                                                                  conv3_8_x2[0][0]
# __________________________________________________________________________________________________
# conv3_9_x1_bn (BatchNormalizati (None, 28, 28, 576)  2304        concatenate_14[0][0]
# __________________________________________________________________________________________________
# conv3_9_x1_scale (Scale)        (None, 28, 28, 576)  1152        conv3_9_x1_bn[0][0]
# __________________________________________________________________________________________________
# relu3_9_x1 (Activation)         (None, 28, 28, 576)  0           conv3_9_x1_scale[0][0]
# __________________________________________________________________________________________________
# conv3_9_x1 (Conv2D)             (None, 28, 28, 192)  110592      relu3_9_x1[0][0]
# __________________________________________________________________________________________________
# conv3_9_x2_bn (BatchNormalizati (None, 28, 28, 192)  768         conv3_9_x1[0][0]
# __________________________________________________________________________________________________
# conv3_9_x2_scale (Scale)        (None, 28, 28, 192)  384         conv3_9_x2_bn[0][0]
# __________________________________________________________________________________________________
# relu3_9_x2 (Activation)         (None, 28, 28, 192)  0           conv3_9_x2_scale[0][0]
# __________________________________________________________________________________________________
# conv3_9_x2_zeropadding (ZeroPad (None, 30, 30, 192)  0           relu3_9_x2[0][0]
# __________________________________________________________________________________________________
# conv3_9_x2 (Conv2D)             (None, 28, 28, 48)   82944       conv3_9_x2_zeropadding[0][0]
# __________________________________________________________________________________________________
# concatenate_15 (Concatenate)    (None, 28, 28, 624)  0           concatenate_14[0][0]
#                                                                  conv3_9_x2[0][0]
# __________________________________________________________________________________________________
# conv3_10_x1_bn (BatchNormalizat (None, 28, 28, 624)  2496        concatenate_15[0][0]
# __________________________________________________________________________________________________
# conv3_10_x1_scale (Scale)       (None, 28, 28, 624)  1248        conv3_10_x1_bn[0][0]
# __________________________________________________________________________________________________
# relu3_10_x1 (Activation)        (None, 28, 28, 624)  0           conv3_10_x1_scale[0][0]
# __________________________________________________________________________________________________
# conv3_10_x1 (Conv2D)            (None, 28, 28, 192)  119808      relu3_10_x1[0][0]
# __________________________________________________________________________________________________
# conv3_10_x2_bn (BatchNormalizat (None, 28, 28, 192)  768         conv3_10_x1[0][0]
# __________________________________________________________________________________________________
# conv3_10_x2_scale (Scale)       (None, 28, 28, 192)  384         conv3_10_x2_bn[0][0]
# __________________________________________________________________________________________________
# relu3_10_x2 (Activation)        (None, 28, 28, 192)  0           conv3_10_x2_scale[0][0]
# __________________________________________________________________________________________________
# conv3_10_x2_zeropadding (ZeroPa (None, 30, 30, 192)  0           relu3_10_x2[0][0]
# __________________________________________________________________________________________________
# conv3_10_x2 (Conv2D)            (None, 28, 28, 48)   82944       conv3_10_x2_zeropadding[0][0]
# __________________________________________________________________________________________________
# concatenate_16 (Concatenate)    (None, 28, 28, 672)  0           concatenate_15[0][0]
#                                                                  conv3_10_x2[0][0]
# __________________________________________________________________________________________________
# conv3_11_x1_bn (BatchNormalizat (None, 28, 28, 672)  2688        concatenate_16[0][0]
# __________________________________________________________________________________________________
# conv3_11_x1_scale (Scale)       (None, 28, 28, 672)  1344        conv3_11_x1_bn[0][0]
# __________________________________________________________________________________________________
# relu3_11_x1 (Activation)        (None, 28, 28, 672)  0           conv3_11_x1_scale[0][0]
# __________________________________________________________________________________________________
# conv3_11_x1 (Conv2D)            (None, 28, 28, 192)  129024      relu3_11_x1[0][0]
# __________________________________________________________________________________________________
# conv3_11_x2_bn (BatchNormalizat (None, 28, 28, 192)  768         conv3_11_x1[0][0]
# __________________________________________________________________________________________________
# conv3_11_x2_scale (Scale)       (None, 28, 28, 192)  384         conv3_11_x2_bn[0][0]
# __________________________________________________________________________________________________
# relu3_11_x2 (Activation)        (None, 28, 28, 192)  0           conv3_11_x2_scale[0][0]
# __________________________________________________________________________________________________
# conv3_11_x2_zeropadding (ZeroPa (None, 30, 30, 192)  0           relu3_11_x2[0][0]
# __________________________________________________________________________________________________
# conv3_11_x2 (Conv2D)            (None, 28, 28, 48)   82944       conv3_11_x2_zeropadding[0][0]
# __________________________________________________________________________________________________
# concatenate_17 (Concatenate)    (None, 28, 28, 720)  0           concatenate_16[0][0]
#                                                                  conv3_11_x2[0][0]
# __________________________________________________________________________________________________
# conv3_12_x1_bn (BatchNormalizat (None, 28, 28, 720)  2880        concatenate_17[0][0]
# __________________________________________________________________________________________________
# conv3_12_x1_scale (Scale)       (None, 28, 28, 720)  1440        conv3_12_x1_bn[0][0]
# __________________________________________________________________________________________________
# relu3_12_x1 (Activation)        (None, 28, 28, 720)  0           conv3_12_x1_scale[0][0]
# __________________________________________________________________________________________________
# conv3_12_x1 (Conv2D)            (None, 28, 28, 192)  138240      relu3_12_x1[0][0]
# __________________________________________________________________________________________________
# conv3_12_x2_bn (BatchNormalizat (None, 28, 28, 192)  768         conv3_12_x1[0][0]
# __________________________________________________________________________________________________
# conv3_12_x2_scale (Scale)       (None, 28, 28, 192)  384         conv3_12_x2_bn[0][0]
# __________________________________________________________________________________________________
# relu3_12_x2 (Activation)        (None, 28, 28, 192)  0           conv3_12_x2_scale[0][0]
# __________________________________________________________________________________________________
# conv3_12_x2_zeropadding (ZeroPa (None, 30, 30, 192)  0           relu3_12_x2[0][0]
# __________________________________________________________________________________________________
# conv3_12_x2 (Conv2D)            (None, 28, 28, 48)   82944       conv3_12_x2_zeropadding[0][0]
# __________________________________________________________________________________________________
# concatenate_18 (Concatenate)    (None, 28, 28, 768)  0           concatenate_17[0][0]
#                                                                  conv3_12_x2[0][0]
# __________________________________________________________________________________________________
# conv3_blk_bn (BatchNormalizatio (None, 28, 28, 768)  3072        concatenate_18[0][0]
# __________________________________________________________________________________________________
# conv3_blk_scale (Scale)         (None, 28, 28, 768)  1536        conv3_blk_bn[0][0]
# __________________________________________________________________________________________________
# relu3_blk (Activation)          (None, 28, 28, 768)  0           conv3_blk_scale[0][0]
# __________________________________________________________________________________________________
# conv3_blk (Conv2D)              (None, 28, 28, 384)  294912      relu3_blk[0][0]
# __________________________________________________________________________________________________
# pool3 (AveragePooling2D)        (None, 14, 14, 384)  0           conv3_blk[0][0]
# __________________________________________________________________________________________________
# conv4_1_x1_bn (BatchNormalizati (None, 14, 14, 384)  1536        pool3[0][0]
# __________________________________________________________________________________________________
# conv4_1_x1_scale (Scale)        (None, 14, 14, 384)  768         conv4_1_x1_bn[0][0]
# __________________________________________________________________________________________________
# relu4_1_x1 (Activation)         (None, 14, 14, 384)  0           conv4_1_x1_scale[0][0]
# __________________________________________________________________________________________________
# conv4_1_x1 (Conv2D)             (None, 14, 14, 192)  73728       relu4_1_x1[0][0]
# __________________________________________________________________________________________________
# conv4_1_x2_bn (BatchNormalizati (None, 14, 14, 192)  768         conv4_1_x1[0][0]
# __________________________________________________________________________________________________
# conv4_1_x2_scale (Scale)        (None, 14, 14, 192)  384         conv4_1_x2_bn[0][0]
# __________________________________________________________________________________________________
# relu4_1_x2 (Activation)         (None, 14, 14, 192)  0           conv4_1_x2_scale[0][0]
# __________________________________________________________________________________________________
# conv4_1_x2_zeropadding (ZeroPad (None, 16, 16, 192)  0           relu4_1_x2[0][0]
# __________________________________________________________________________________________________
# conv4_1_x2 (Conv2D)             (None, 14, 14, 48)   82944       conv4_1_x2_zeropadding[0][0]
# __________________________________________________________________________________________________
# concatenate_19 (Concatenate)    (None, 14, 14, 432)  0           pool3[0][0]
#                                                                  conv4_1_x2[0][0]
# __________________________________________________________________________________________________
# conv4_2_x1_bn (BatchNormalizati (None, 14, 14, 432)  1728        concatenate_19[0][0]
# __________________________________________________________________________________________________
# conv4_2_x1_scale (Scale)        (None, 14, 14, 432)  864         conv4_2_x1_bn[0][0]
# __________________________________________________________________________________________________
# relu4_2_x1 (Activation)         (None, 14, 14, 432)  0           conv4_2_x1_scale[0][0]
# __________________________________________________________________________________________________
# conv4_2_x1 (Conv2D)             (None, 14, 14, 192)  82944       relu4_2_x1[0][0]
# __________________________________________________________________________________________________
# conv4_2_x2_bn (BatchNormalizati (None, 14, 14, 192)  768         conv4_2_x1[0][0]
# __________________________________________________________________________________________________
# conv4_2_x2_scale (Scale)        (None, 14, 14, 192)  384         conv4_2_x2_bn[0][0]
# __________________________________________________________________________________________________
# relu4_2_x2 (Activation)         (None, 14, 14, 192)  0           conv4_2_x2_scale[0][0]
# __________________________________________________________________________________________________
# conv4_2_x2_zeropadding (ZeroPad (None, 16, 16, 192)  0           relu4_2_x2[0][0]
# __________________________________________________________________________________________________
# conv4_2_x2 (Conv2D)             (None, 14, 14, 48)   82944       conv4_2_x2_zeropadding[0][0]
# __________________________________________________________________________________________________
# concatenate_20 (Concatenate)    (None, 14, 14, 480)  0           concatenate_19[0][0]
#                                                                  conv4_2_x2[0][0]
# __________________________________________________________________________________________________
# conv4_3_x1_bn (BatchNormalizati (None, 14, 14, 480)  1920        concatenate_20[0][0]
# __________________________________________________________________________________________________
# conv4_3_x1_scale (Scale)        (None, 14, 14, 480)  960         conv4_3_x1_bn[0][0]
# __________________________________________________________________________________________________
# relu4_3_x1 (Activation)         (None, 14, 14, 480)  0           conv4_3_x1_scale[0][0]
# __________________________________________________________________________________________________
# conv4_3_x1 (Conv2D)             (None, 14, 14, 192)  92160       relu4_3_x1[0][0]
# __________________________________________________________________________________________________
# conv4_3_x2_bn (BatchNormalizati (None, 14, 14, 192)  768         conv4_3_x1[0][0]
# __________________________________________________________________________________________________
# conv4_3_x2_scale (Scale)        (None, 14, 14, 192)  384         conv4_3_x2_bn[0][0]
# __________________________________________________________________________________________________
# relu4_3_x2 (Activation)         (None, 14, 14, 192)  0           conv4_3_x2_scale[0][0]
# __________________________________________________________________________________________________
# conv4_3_x2_zeropadding (ZeroPad (None, 16, 16, 192)  0           relu4_3_x2[0][0]
# __________________________________________________________________________________________________
# conv4_3_x2 (Conv2D)             (None, 14, 14, 48)   82944       conv4_3_x2_zeropadding[0][0]
# __________________________________________________________________________________________________
# concatenate_21 (Concatenate)    (None, 14, 14, 528)  0           concatenate_20[0][0]
#                                                                  conv4_3_x2[0][0]
# __________________________________________________________________________________________________
# conv4_4_x1_bn (BatchNormalizati (None, 14, 14, 528)  2112        concatenate_21[0][0]
# __________________________________________________________________________________________________
# conv4_4_x1_scale (Scale)        (None, 14, 14, 528)  1056        conv4_4_x1_bn[0][0]
# __________________________________________________________________________________________________
# ...
# conv5_18_x1_bn (BatchNormalizat (None, 7, 7, 1872)   7488        concatenate_71[0][0]
# __________________________________________________________________________________________________
# conv5_18_x1_scale (Scale)       (None, 7, 7, 1872)   3744        conv5_18_x1_bn[0][0]
# __________________________________________________________________________________________________
# relu5_18_x1 (Activation)        (None, 7, 7, 1872)   0           conv5_18_x1_scale[0][0]
# __________________________________________________________________________________________________
# conv5_18_x1 (Conv2D)            (None, 7, 7, 192)    359424      relu5_18_x1[0][0]
# __________________________________________________________________________________________________
# conv5_18_x2_bn (BatchNormalizat (None, 7, 7, 192)    768         conv5_18_x1[0][0]
# __________________________________________________________________________________________________
# conv5_18_x2_scale (Scale)       (None, 7, 7, 192)    384         conv5_18_x2_bn[0][0]
# __________________________________________________________________________________________________
# relu5_18_x2 (Activation)        (None, 7, 7, 192)    0           conv5_18_x2_scale[0][0]
# __________________________________________________________________________________________________
# conv5_18_x2_zeropadding (ZeroPa (None, 9, 9, 192)    0           relu5_18_x2[0][0]
# __________________________________________________________________________________________________
# conv5_18_x2 (Conv2D)            (None, 7, 7, 48)     82944       conv5_18_x2_zeropadding[0][0]
# __________________________________________________________________________________________________
# concatenate_72 (Concatenate)    (None, 7, 7, 1920)   0           concatenate_71[0][0]
#                                                                  conv5_18_x2[0][0]
# __________________________________________________________________________________________________
# conv5_19_x1_bn (BatchNormalizat (None, 7, 7, 1920)   7680        concatenate_72[0][0]
# __________________________________________________________________________________________________
# conv5_19_x1_scale (Scale)       (None, 7, 7, 1920)   3840        conv5_19_x1_bn[0][0]
# __________________________________________________________________________________________________
# relu5_19_x1 (Activation)        (None, 7, 7, 1920)   0           conv5_19_x1_scale[0][0]
# __________________________________________________________________________________________________
# conv5_19_x1 (Conv2D)            (None, 7, 7, 192)    368640      relu5_19_x1[0][0]
# __________________________________________________________________________________________________
# conv5_19_x2_bn (BatchNormalizat (None, 7, 7, 192)    768         conv5_19_x1[0][0]
# __________________________________________________________________________________________________
# conv5_19_x2_scale (Scale)       (None, 7, 7, 192)    384         conv5_19_x2_bn[0][0]
# __________________________________________________________________________________________________
# relu5_19_x2 (Activation)        (None, 7, 7, 192)    0           conv5_19_x2_scale[0][0]
# __________________________________________________________________________________________________
# conv5_19_x2_zeropadding (ZeroPa (None, 9, 9, 192)    0           relu5_19_x2[0][0]
# __________________________________________________________________________________________________
# conv5_19_x2 (Conv2D)            (None, 7, 7, 48)     82944       conv5_19_x2_zeropadding[0][0]
# __________________________________________________________________________________________________
# concatenate_73 (Concatenate)    (None, 7, 7, 1968)   0           concatenate_72[0][0]
#                                                                  conv5_19_x2[0][0]
# __________________________________________________________________________________________________
# conv5_20_x1_bn (BatchNormalizat (None, 7, 7, 1968)   7872        concatenate_73[0][0]
# __________________________________________________________________________________________________
# conv5_20_x1_scale (Scale)       (None, 7, 7, 1968)   3936        conv5_20_x1_bn[0][0]
# __________________________________________________________________________________________________
# relu5_20_x1 (Activation)        (None, 7, 7, 1968)   0           conv5_20_x1_scale[0][0]
# __________________________________________________________________________________________________
# conv5_20_x1 (Conv2D)            (None, 7, 7, 192)    377856      relu5_20_x1[0][0]
# __________________________________________________________________________________________________
# conv5_20_x2_bn (BatchNormalizat (None, 7, 7, 192)    768         conv5_20_x1[0][0]
# __________________________________________________________________________________________________
# conv5_20_x2_scale (Scale)       (None, 7, 7, 192)    384         conv5_20_x2_bn[0][0]
# __________________________________________________________________________________________________
# relu5_20_x2 (Activation)        (None, 7, 7, 192)    0           conv5_20_x2_scale[0][0]
# __________________________________________________________________________________________________
# conv5_20_x2_zeropadding (ZeroPa (None, 9, 9, 192)    0           relu5_20_x2[0][0]
# __________________________________________________________________________________________________
# conv5_20_x2 (Conv2D)            (None, 7, 7, 48)     82944       conv5_20_x2_zeropadding[0][0]
# __________________________________________________________________________________________________
# concatenate_74 (Concatenate)    (None, 7, 7, 2016)   0           concatenate_73[0][0]
#                                                                  conv5_20_x2[0][0]
# __________________________________________________________________________________________________
# conv5_21_x1_bn (BatchNormalizat (None, 7, 7, 2016)   8064        concatenate_74[0][0]
# __________________________________________________________________________________________________
# conv5_21_x1_scale (Scale)       (None, 7, 7, 2016)   4032        conv5_21_x1_bn[0][0]
# __________________________________________________________________________________________________
# relu5_21_x1 (Activation)        (None, 7, 7, 2016)   0           conv5_21_x1_scale[0][0]
# __________________________________________________________________________________________________
# conv5_21_x1 (Conv2D)            (None, 7, 7, 192)    387072      relu5_21_x1[0][0]
# __________________________________________________________________________________________________
# conv5_21_x2_bn (BatchNormalizat (None, 7, 7, 192)    768         conv5_21_x1[0][0]
# __________________________________________________________________________________________________
# conv5_21_x2_scale (Scale)       (None, 7, 7, 192)    384         conv5_21_x2_bn[0][0]
# __________________________________________________________________________________________________
# relu5_21_x2 (Activation)        (None, 7, 7, 192)    0           conv5_21_x2_scale[0][0]
# __________________________________________________________________________________________________
# conv5_21_x2_zeropadding (ZeroPa (None, 9, 9, 192)    0           relu5_21_x2[0][0]
# __________________________________________________________________________________________________
# conv5_21_x2 (Conv2D)            (None, 7, 7, 48)     82944       conv5_21_x2_zeropadding[0][0]
# __________________________________________________________________________________________________
# concatenate_75 (Concatenate)    (None, 7, 7, 2064)   0           concatenate_74[0][0]
#                                                                  conv5_21_x2[0][0]
# __________________________________________________________________________________________________
# conv5_22_x1_bn (BatchNormalizat (None, 7, 7, 2064)   8256        concatenate_75[0][0]
# __________________________________________________________________________________________________
# conv5_22_x1_scale (Scale)       (None, 7, 7, 2064)   4128        conv5_22_x1_bn[0][0]
# __________________________________________________________________________________________________
# relu5_22_x1 (Activation)        (None, 7, 7, 2064)   0           conv5_22_x1_scale[0][0]
# __________________________________________________________________________________________________
# conv5_22_x1 (Conv2D)            (None, 7, 7, 192)    396288      relu5_22_x1[0][0]
# __________________________________________________________________________________________________
# conv5_22_x2_bn (BatchNormalizat (None, 7, 7, 192)    768         conv5_22_x1[0][0]
# __________________________________________________________________________________________________
# conv5_22_x2_scale (Scale)       (None, 7, 7, 192)    384         conv5_22_x2_bn[0][0]
# __________________________________________________________________________________________________
# relu5_22_x2 (Activation)        (None, 7, 7, 192)    0           conv5_22_x2_scale[0][0]
# __________________________________________________________________________________________________
# conv5_22_x2_zeropadding (ZeroPa (None, 9, 9, 192)    0           relu5_22_x2[0][0]
# __________________________________________________________________________________________________
# conv5_22_x2 (Conv2D)            (None, 7, 7, 48)     82944       conv5_22_x2_zeropadding[0][0]
# __________________________________________________________________________________________________
# concatenate_76 (Concatenate)    (None, 7, 7, 2112)   0           concatenate_75[0][0]
#                                                                  conv5_22_x2[0][0]
# __________________________________________________________________________________________________
# conv5_23_x1_bn (BatchNormalizat (None, 7, 7, 2112)   8448        concatenate_76[0][0]
# __________________________________________________________________________________________________
# conv5_23_x1_scale (Scale)       (None, 7, 7, 2112)   4224        conv5_23_x1_bn[0][0]
# __________________________________________________________________________________________________
# relu5_23_x1 (Activation)        (None, 7, 7, 2112)   0           conv5_23_x1_scale[0][0]
# __________________________________________________________________________________________________
# conv5_23_x1 (Conv2D)            (None, 7, 7, 192)    405504      relu5_23_x1[0][0]
# __________________________________________________________________________________________________
# conv5_23_x2_bn (BatchNormalizat (None, 7, 7, 192)    768         conv5_23_x1[0][0]
# __________________________________________________________________________________________________
# conv5_23_x2_scale (Scale)       (None, 7, 7, 192)    384         conv5_23_x2_bn[0][0]
# __________________________________________________________________________________________________
# relu5_23_x2 (Activation)        (None, 7, 7, 192)    0           conv5_23_x2_scale[0][0]
# __________________________________________________________________________________________________
# conv5_23_x2_zeropadding (ZeroPa (None, 9, 9, 192)    0           relu5_23_x2[0][0]
# __________________________________________________________________________________________________
# conv5_23_x2 (Conv2D)            (None, 7, 7, 48)     82944       conv5_23_x2_zeropadding[0][0]
# __________________________________________________________________________________________________
# concatenate_77 (Concatenate)    (None, 7, 7, 2160)   0           concatenate_76[0][0]
#                                                                  conv5_23_x2[0][0]
# __________________________________________________________________________________________________
# conv5_24_x1_bn (BatchNormalizat (None, 7, 7, 2160)   8640        concatenate_77[0][0]
# __________________________________________________________________________________________________
# conv5_24_x1_scale (Scale)       (None, 7, 7, 2160)   4320        conv5_24_x1_bn[0][0]
# __________________________________________________________________________________________________
# relu5_24_x1 (Activation)        (None, 7, 7, 2160)   0           conv5_24_x1_scale[0][0]
# __________________________________________________________________________________________________
# conv5_24_x1 (Conv2D)            (None, 7, 7, 192)    414720      relu5_24_x1[0][0]
# __________________________________________________________________________________________________
# conv5_24_x2_bn (BatchNormalizat (None, 7, 7, 192)    768         conv5_24_x1[0][0]
# __________________________________________________________________________________________________
# conv5_24_x2_scale (Scale)       (None, 7, 7, 192)    384         conv5_24_x2_bn[0][0]
# __________________________________________________________________________________________________
# relu5_24_x2 (Activation)        (None, 7, 7, 192)    0           conv5_24_x2_scale[0][0]
# __________________________________________________________________________________________________
# conv5_24_x2_zeropadding (ZeroPa (None, 9, 9, 192)    0           relu5_24_x2[0][0]
# __________________________________________________________________________________________________
# conv5_24_x2 (Conv2D)            (None, 7, 7, 48)     82944       conv5_24_x2_zeropadding[0][0]
# __________________________________________________________________________________________________
# concatenate_78 (Concatenate)    (None, 7, 7, 2208)   0           concatenate_77[0][0]
#                                                                  conv5_24_x2[0][0]
# __________________________________________________________________________________________________
# conv5_blk_bn (BatchNormalizatio (None, 7, 7, 2208)   8832        concatenate_78[0][0]
# __________________________________________________________________________________________________
# conv5_blk_scale (Scale)         (None, 7, 7, 2208)   4416        conv5_blk_bn[0][0]
# __________________________________________________________________________________________________
# relu5_blk (Activation)          (None, 7, 7, 2208)   0           conv5_blk_scale[0][0]
# __________________________________________________________________________________________________
# pool5 (GlobalAveragePooling2D)  (None, 2208)         0           relu5_blk[0][0]
# __________________________________________________________________________________________________
# fc6 (Dense)                     (None, 12)           26508       pool5[0][0]
# __________________________________________________________________________________________________
# prob (Activation)               (None, 12)           0           fc6[0][0]
# ==================================================================================================
# Total params: 26,938,380
# Trainable params: 26,718,444
# Non-trainable params: 219,936
# __________________________________________________________________________________________________

# %%
for layer in model.layers:
    layer.W_regularizer = l2(1e-2)
    layer.trainable = True

opt = SGD(lr=lr, decay=1e-8, momentum=0.9, nesterov=True)
model.compile(loss='categorical_crossentropy', optimizer=opt, metrics=['accuracy'])

# %%
# load for re-training
model.load_weights('./checkpoints/Best/%s_acc-best.h5' % model_name)

model.fit_generator(
    generator=train_generator,
    validation_data=val_generator,
    steps_per_epoch=num_steps_per_epoch,
    callbacks=snapshot.get_callbacks(model_prefix=model_name),
    # initial_epoch=pre_train_epochs,
    epochs=num_epochs,
    shuffle=True,
    validation_steps=num_steps_per_epoch,
    verbose=1)

# save trained weights
train_end_weights = './checkpoints/%s_train-end.h5' % model_name

model.save_weights(train_end_weights, overwrite=True)
# Out:
# Epoch 1/200
# 300/300 [==============================] - 184s 613ms/step - loss: 0.0742 - acc: 0.9742 - val_loss: 0.0865 - val_acc: 0.9736
#
# Epoch 00001: val_acc improved from -inf to 0.97364, saving model to ./checkpoints/DenseNet-161_acc-best.h5
# Epoch 2/200
# 300/300 [==============================] - 128s 426ms/step - loss: 0.0827 - acc: 0.9758 - val_loss: 0.0798 - val_acc: 0.9774
#
# Epoch 00002: val_acc improved from 0.97364 to 0.97736, saving model to ./checkpoints/DenseNet-161_acc-best.h5
# Epoch 3/200
# 300/300 [==============================] - 128s 427ms/step - loss: 0.0645 - acc: 0.9817 - val_loss: 0.0966 - val_acc: 0.9682
#
# Epoch 00003: val_acc did not improve from 0.97736
# Epoch 4/200
# 300/300 [==============================] - 127s 424ms/step - loss: 0.0603 - acc: 0.9800 - val_loss: 0.0979 - val_acc: 0.9639
#
# Epoch 00004: val_acc did not improve from 0.97736
# Epoch 5/200
# 300/300 [==============================] - 128s 427ms/step - loss: 0.0710 - acc: 0.9800 - val_loss: 0.0989 - val_acc: 0.9669
#
# Epoch 00005: val_acc did not improve from 0.97736
# Epoch 6/200
# 300/300 [==============================] - 127s 424ms/step - loss: 0.0661 - acc: 0.9804 - val_loss: 0.1034 - val_acc: 0.9635
#
# Epoch 00006: val_acc did not improve from 0.97736
# Epoch 7/200
# 300/300 [==============================] - 128s 425ms/step - loss: 0.0655 - acc: 0.9775 - val_loss: 0.0969 - val_acc: 0.9707
#
# Epoch 00007: val_acc did not improve from 0.97736
# Epoch 8/200
# 300/300 [==============================] - 128s 426ms/step - loss: 0.0670 - acc: 0.9792 - val_loss: 0.1338 - val_acc: 0.9652
#
# Epoch 00008: val_acc did not improve from 0.97736
# Epoch 9/200
# 300/300 [==============================] - 128s 426ms/step - loss: 0.0574 - acc: 0.9829 - val_loss: 0.1215 - val_acc: 0.9644
#
# Epoch 00009: val_acc did not improve from 0.97736
# Epoch 10/200
# 300/300 [==============================] - 127s 423ms/step - loss: 0.0725 - acc: 0.9781 - val_loss: 0.0885 - val_acc: 0.9719
#
# Epoch 00010: val_acc did not improve from 0.97736
# Epoch 11/200
# 300/300 [==============================] - 128s 426ms/step - loss: 0.0514 - acc: 0.9867 - val_loss: 0.0844 - val_acc: 0.9736
#
# Epoch 00011: val_acc did not improve from 0.97736
# Epoch 12/200
# 300/300 [==============================] - 128s 427ms/step - loss: 0.0608 - acc: 0.9812 - val_loss: 0.1182 - val_acc: 0.9639
#
# Epoch 00012: val_acc did not improve from 0.97736
# Epoch 13/200
# 300/300 [==============================] - 128s 427ms/step - loss: 0.0486 - acc: 0.9862 - val_loss: 0.0919 - val_acc: 0.9649
#
# Epoch 00013: val_acc did not improve from 0.97736
# Epoch 14/200
# 300/300 [==============================] - 128s 427ms/step - loss: 0.0498 - acc: 0.9846 - val_loss: 0.1057 - val_acc: 0.9568
#
# Epoch 00014: val_acc did not improve from 0.97736
# Epoch 15/200
# 300/300 [==============================] - 128s 426ms/step - loss: 0.0545 - acc: 0.9800 - val_loss: 0.1033 - val_acc: 0.9649
#
# Epoch 00015: val_acc did not improve from 0.97736
# Epoch 16/200
# 300/300 [==============================] - 128s 425ms/step - loss: 0.0491 - acc: 0.9871 - val_loss: 0.0946 - val_acc: 0.9639
#
# Epoch 00016: val_acc did not improve from 0.97736
# Epoch 17/200
# 300/300 [==============================] - 128s 426ms/step - loss: 0.0478 - acc: 0.9862 - val_loss: 0.1129 - val_acc: 0.9678
#
# Epoch 00017: val_acc did not improve from 0.97736
# Epoch 18/200
# 300/300 [==============================] - 127s 424ms/step - loss: 0.0371 - acc: 0.9887 - val_loss: 0.0866 - val_acc: 0.9719
#
# Epoch 00018: val_acc did not improve from 0.97736
# Epoch 19/200
# 300/300 [==============================] - 128s 426ms/step - loss: 0.0474 - acc: 0.9879 - val_loss: 0.0972 - val_acc: 0.9644
#
# Epoch 00019: val_acc did not improve from 0.97736
# Epoch 20/200
# 300/300 [==============================] - 128s 426ms/step - loss: 0.0483 - acc: 0.9862 - val_loss: 0.0917 - val_acc: 0.9660
#
# Epoch 00020: val_acc did not improve from 0.97736
# Epoch 21/200
# 300/300 [==============================] - 127s 423ms/step - loss: 0.0389 - acc: 0.9921 - val_loss: 0.1037 - val_acc: 0.9640
#
# Epoch 00021: val_acc did not improve from 0.97736
# Epoch 22/200
# 300/300 [==============================] - 127s 424ms/step - loss: 0.0419 - acc: 0.9875 - val_loss: 0.1045 - val_acc: 0.9635
#
# Epoch 00022: val_acc did not improve from 0.97736
# Epoch 23/200
# 300/300 [==============================] - 127s 425ms/step - loss: 0.0373 - acc: 0.9887 - val_loss: 0.0935 - val_acc: 0.9686
#
# Epoch 00023: val_acc did not improve from 0.97736
# Epoch 24/200
# 300/300 [==============================] - 127s 424ms/step - loss: 0.0462 - acc: 0.9876 - val_loss: 0.1081 - val_acc: 0.9614
#
# Epoch 00024: val_acc did not improve from 0.97736
# Epoch 25/200
# 300/300 [==============================] - 127s 424ms/step - loss: 0.0373 - acc: 0.9879 - val_loss: 0.0908 - val_acc: 0.9677
#
# Epoch 00025: val_acc did not improve from 0.97736
# Epoch 26/200
# 300/300 [==============================] - 126s 420ms/step - loss: 0.0376 - acc: 0.9875 - val_loss: 0.0952 - val_acc: 0.9678
#
# Epoch 00026: val_acc did not improve from 0.97736
# Epoch 27/200
# 300/300 [==============================] - 128s 427ms/step - loss: 0.0354 - acc: 0.9921 - val_loss: 0.0939 - val_acc: 0.9652
#
# Epoch 00027: val_acc did not improve from 0.97736
# Epoch 28/200
# 300/300 [==============================] - 127s 424ms/step - loss: 0.0372 - acc: 0.9892 - val_loss: 0.0949 - val_acc: 0.9682
#
# Epoch 00028: val_acc did not improve from 0.97736
# Epoch 29/200
# 300/300 [==============================] - 127s 424ms/step - loss: 0.0343 - acc: 0.9910 - val_loss: 0.0886 - val_acc: 0.9706
#
# Epoch 00029: val_acc did not improve from 0.97736
# Epoch 30/200
# 300/300 [==============================] - 127s 424ms/step - loss: 0.0392 - acc: 0.9912 - val_loss: 0.0936 - val_acc: 0.9686
#
# Epoch 00030: val_acc did not improve from 0.97736
# Epoch 31/200
# 300/300 [==============================] - 128s 426ms/step - loss: 0.0316 - acc: 0.9908 - val_loss: 0.0930 - val_acc: 0.9694
#
# Epoch 00031: val_acc did not improve from 0.97736
# Epoch 32/200
# 300/300 [==============================] - 127s 424ms/step - loss: 0.0421 - acc: 0.9875 - val_loss: 0.0938 - val_acc: 0.9665
#
# Epoch 00032: val_acc did not improve from 0.97736
# Epoch 00032: early stopping

# %%
# load test images
test_set = pd.read_csv(data_set_path + "sample_submission.csv")

test_fn = []
test_img = np.zeros((794, img_rows, img_cols, img_channel), dtype=np.float32)
for i, f in enumerate(test_set['file']):
    test_fn.append(f)

    img = read_img("test/" + f) / 225.
    img = np.expand_dims(img[:], axis=0)

    test_img[i] = img

print("[*] test image shape : {} size : {:,}".format(test_img.shape, test_img.size))
# Out:
# [*] test image shape : (794, 224, 224, 3) size : 119,519,232

# %%
model_file_name = ["./checkpoints/%s_acc-best.h5" % model_name]
for i in range(1, num_snapshots + 1):
    model_file_name.append("./checkpoints/%s-%d.h5" % (model_name, i))

# %%
# Ensemble
test_preds = []
saved_total = 0
for weight in model_file_name:
    try:
        model.load_weights(weight, by_name=True)
    except OSError:
        continue

    print("[*] predict with %s" % weight.split('/')[-1])

    test_pred = model.predict(test_img, batch_size=batch_size)
    test_preds.append(test_pred)

    saved_total += 1

pred_weights = [1. / saved_total] * saved_total

weighted_predictions = np.zeros((794, num_categories), dtype='float32')
for weight, prediction in zip(pred_weights, test_preds):
    weighted_predictions += weight * prediction

preds = np.argmax(weighted_predictions, axis=1)
print(preds, preds.shape)

test_set['species'] = [categories[c] for c in preds]
test_set.to_csv("./submit.csv", index=None)

# This is how i actually did.
# 1. Running this script, many times. 
# 2. Getting best-acc.h5 (model file) from each runnings.
# 2-1. (After first running, use beforehand best-acc.h5 to initialize model weights instead of orignal DenseNet-161-48 pre-trained model.)
# 3. Ensembling all of it! (maybe 4~5 best-acc models), (except SnapShoted model file generated by SnapShot Ensemble Callback)
# 4. Then, submit!

# Hyper-parameters
# 1. Batch Size : Because of my GPU spec..., i just use 8 batch_size instead of 16.
# 2. Weight Regularizer : I just test all of cases from 1e-2 to 5e-4.
# 3. Opzimier : SGD with LR 2e-4, nestorv

# Callbacks
# 1. Learning Rate Scheduler : I used this one. https://github.com/titu1994/Snapshot-Ensembles
# 2. Eaerly Stop : patience 30 by 'val_loss'
# 3. ...

# Augumentation
# 1. shift range : maybe 0.2 to 0.3 is proper.
# 2. rotate range : there's no problem setting rot range to 360 on this DataSet (plant seedlings). But i just try some cases (~60 and 360) with same model, then ~60 got higher acc than 360.
# 3. flip : horizontal & vertical_flip could be find.

# Model
# I used many models like Xception, Inception-v3, VGG16, DenseNet-161-48, ....
# But, on my machine, DensenNet-161-48 got highest test acc with same hyper-parameters. So i just used it... :)
# 
# Here is DenseNet-161-48 pre-trained file link : https://github.com/titu1994/DenseNet/releases/download/v3.0/DenseNet-BC-161-48-no-top.h5
# Which got from here : https://github.com/titu1994/DenseNet

# Train/Validation/Test
# Train : Val = 0.85 : 0.15

# Maybe, on average, about 100 mins are taken on GPU 1060 6GB (because of EealyStop Callback).
# Out:
# [*] predict with DenseNet-161_acc-best.h5
# [10  5 11  3 11  6  3  5  6  6  5 10 11  8 11  5  8  8  3  9  3 10  9 11
#  11  7  8  8  3 11  3  9  0 11  6  0  6  6  3  7  0  4  3 10 11 11  7  8
#   7 10  6 11  2  6  7  5  1 10  2  6 11  2  1  4  7  5  6  6  9  8 10  3
#   8  3  3  4  6  8  8  6 11  3  3  4  9 11  2  8  5  6  1  6  5  6  3  6
#  10  8  7 10  5  5  8 11  5  5  3  8  2  2  6  1  3  9  9 11  2  1 11  3
#   3 11  2  6  7  4  1  7  5  3 11 11  3  3  5  4  5  1  6  3  6 10  9  3
#   5 11  4 10 11  1  8  6  7  8  6 10  3  5  6  2  1  6  8  8  9  0  8  4
#   3  3  9  7  9  3  3 10  0  2  0  6  6 10  6  6  8  6  3  5  5 10  6  1
#   8  4  1  0  4  3  6  3  2  6  1  1 10  2  5  3  5  9  5  1  5  6 10  2
#   7  6 10  3  8  8  3 10  4  5  5  3  3  7  9  2  9  2  3  0  0  2 10  1
#  11  3  7 10  2  9  6  5 10  5  3  6  7  3  3  4  2  1 10  3  6  7  3  7
#  10  2  5  9  8  9  1  0  6 10  3 10  8  3  5  2  6  6  7 11  7  0  3  3
#   7  3  6  8  1  7 10 11  6  6 10  5  9  3  2 10 11 11  1  6  4  2 11  6
#   8  4  9  6 11  1  6 10 11  1  1 10 10 10  4 11 10 11  1  8  6  0 11  2
#   2  9  0  9 10  8  3  1  2  5  9  7  0 11  6  5  6  1  5  6  6  3  8 10
#  10  3  1  2  6  1  0  8 10 10 11  3  3  1 11 11  6  6  4  3  1 11  6  8
#   6  6  8 11  3  3  6 11  8  8  5  1  9  1  9  3  7 11  8  9  1  6  5 10
#   8  4  0  6 10 10  0 11  5  3 11  5  1  3  6  6  7 10  8  2 11 10  6  2
#   5 10 10 10  6  6  5  6  3  1  8  0  3  3  1  8 11 10  3 10  8  9 11  3
#   8  1  3 11  3 10  2  0  5  1  0  1  0  8 10 11  4  3  9 10  3  9  8  0
#   4  4  6  6  1  8 11  6  4  3  6  6  4 10 10  5  3  7 10 10  1  9  7  2
#   0  6 10  1 10  3 10  6  6  6  8  3  7  9  3  5 11 11  5  8 10  1 11  9
#   1  6  6  8  0  3  9 11  0  2  4  8  3  6  6  3  6  6  3  9  6  8 10 10
#   6  6  0  2  8  2  2  4  0  2  3  3  7  9  5  8  7  0  6  0  5 10  6  8
#   4  5  9  7 11  6  8  8  6  2  8 11  5  8  3  8  0  6  8  8  8  9  7 11
#   8  3  5  8  8 10 10  8  7  6  3 10  8  1  5  6  8  3  6 11 11  2  6  3
#   9  8  8  8  4  5  3 10  4  3  9  1  6  5  7  1 11  0 10 10  1  3  0  2
#   6  3  7  8  1  5  6 11  6  4  2 10  8  1  3  0  5  3  8  4  0  5  8  0
#   0 10  8  8  5  3 10  3  6 11  8  1  3  0  1 10  6  6 11  8  3 11 10  5
#  11  6  3  6 11  0  3  8  8  1  1  6 11  2  1 11  7  0 11  4  6  8  5  4
#  11  8  0  5 11 10  6  2 10  5  5  9  0  3  9 10 10  2  8  1  6 11  3  6
#   8  8  1  1 11  6  9  6 10  2  8  6  2  5  5  1  8 11  1 10 11  7  9  8
#   9  2  5  3  9  2  1 11  6  1  8 11  2  6  3  4  6  4  8  8  9  6 11 11
#   1  4] (794,)
